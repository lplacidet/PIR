# %%
# Import all libraries needed for the tutorial

# General syntax to import specific functions in a library: 
##from (library) import (specific library function)
from pandas import DataFrame, read_csv

# General syntax to import a library but no functions: 
##import (library) as (give the library a nickname/alias)
import matplotlib.pyplot as plt
import pandas as pd #this is how I usually import pandas
import sys #only needed to determine Python version number
import matplotlib #only needed to determine Matplotlib version number

# Enable inline plotting
# %matplotlib inline

# %%
print('Python version ' + sys.version)
print('Pandas version ' + pd.__version__)
print('Matplotlib version ' + matplotlib.__version__)
# Out:
# Python version 3.7.4 (default, Aug 13 2019, 15:17:50)
# [Clang 4.0.1 (tags/RELEASE_401/final)]
# Pandas version 0.25.1
# Matplotlib version 3.1.1

# %%
# file path of csv file
Location = r'/Users/louiseplacidet/Desktop/PIR/Data/data_spikes/E18KABaseline_BcutFiltered.txt'

# create dataframe
df = pd.read_csv(Location, sep='\t',skiprows=[0,1,3])
df
# Out:
#          %t             Fi 21         Fi 31         Fi 41         \
# 0                 0.00         -0.45          2.39         -0.68
# 1                 0.04          0.45          2.39         -1.93
# 2                 0.08          0.91          1.36         -3.18
# 3                 0.12          0.57          0.11         -3.30
# 4                 0.16          0.11         -0.68         -2.50
# ...                ...           ...           ...           ...
# 7544995      301799.80          3.41          2.73          0.34
# 7544996      301799.84          3.98          1.25          0.57
# 7544997      301799.88          3.52         -0.34          1.25
# 7544998      301799.92          2.50         -2.05          1.48
# 7544999      301799.96          1.14         -3.98          0.91
#
#          Fi 22         Fi 32         Fi 42         Fi 23         Fi 33         \
# 0               -2.50         -0.23         -0.45          0.11          3.86
# ...

# %%
list(df.columns.values)
# Out:
# ['%t           ',
#  'Fi 21       ',
#  'Fi 31       ',
#  'Fi 41       ',
#  'Fi 22       ',
#  'Fi 32       ',
#  'Fi 42       ',
#  'Fi 23       ',
#  'Fi 33       ',
#  'Fi 43       ']

# %%
df = pd.read_csv(Location, sep='\t',skiprows=[0,1,3] , index_col='%t           ')
df
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/numpy/lib/arraysetops.py:568: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)
#                Fi 21         Fi 31         Fi 41         Fi 22         \
# %t
# 0.00                  -0.45          2.39         -0.68         -2.50
# 0.04                   0.45          2.39         -1.93         -1.93
# 0.08                   0.91          1.36         -3.18         -1.59
# 0.12                   0.57          0.11         -3.30         -1.25
# 0.16                   0.11         -0.68         -2.50         -1.02
# ...                     ...           ...           ...           ...
# 301799.80              3.41          2.73          0.34         -3.30
# 301799.84              3.98          1.25          0.57         -1.59
# 301799.88              3.52         -0.34          1.25         -0.11
# ...

# %%
list(df.columns.values)
# Out:
# ['Fi 21       ',
#  'Fi 31       ',
#  'Fi 41       ',
#  'Fi 22       ',
#  'Fi 32       ',
#  'Fi 42       ',
#  'Fi 23       ',
#  'Fi 33       ',
#  'Fi 43       ']

# %%
ax = df['Fi 21       '].plot(figsize=(100,10), title='El 21 Filtered')
ax.set_xlabel("time")
ax.set_ylabel("Amplitude [µV]")
# Out:
# Text(0, 0.5, 'Amplitude [µV]')

# %%
for col in df.columns:
    df[col].plot(figsize=(100,10), title='All Electrodes');
