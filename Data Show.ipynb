# %%
# Import all libraries needed for the tutorial

# General syntax to import specific functions in a library: 
##from (library) import (specific library function)
from pandas import DataFrame, read_csv

# General syntax to import a library but no functions: 
##import (library) as (give the library a nickname/alias)
import matplotlib.pyplot as plt
import pandas as pd #this is how I usually import pandas
import sys #only needed to determine Python version number
import matplotlib #only needed to determine Matplotlib version number

# Enable inline plotting
# %matplotlib inline

# %%
print('Python version ' + sys.version)
print('Pandas version ' + pd.__version__)
print('Matplotlib version ' + matplotlib.__version__)
# Out:
# Python version 3.7.4 (default, Aug 13 2019, 15:17:50)
# [Clang 4.0.1 (tags/RELEASE_401/final)]
# Pandas version 0.25.1
# Matplotlib version 3.1.1

# %%
# file path of csv file
Location = r'/Users/louiseplacidet/Desktop/PIR/Data/data_spikes/E18KABaseline_Bcut.txt'

# create dataframe
df = pd.read_csv(Location, sep='\t',skiprows=[0,1,3])
df
# Out:
#          %t             El 21         El 31         El 41         \
# 0                 0.00         -2.84         -1.02         -7.05
# 1                 0.04         -3.41         -3.30         -8.07
# 2                 0.08         -4.77         -3.86         -5.80
# 3                 0.12         -5.00         -3.41         -4.32
# 4                 0.16         -3.30         -4.20         -4.09
# ...                ...           ...           ...           ...
# 7544995      301799.80          0.68          0.68          0.23
# 7544996      301799.84         -1.02         -1.14          0.91
# 7544997      301799.88         -1.14         -3.41          0.91
# 7544998      301799.92         -2.50         -6.36         -1.59
# 7544999      301799.96         -4.55         -6.93         -4.32
#
#          El 22         El 32         El 42         El 23         El 33         \
# 0               -3.18         -3.41         -3.30         -2.27         -1.36
# ...

# %%
#df.rename(columns={"%t           ": "t", "El 21       ": "EL 21", "El 31       ": "El 31", "El 41       ": "El 41", "El 22       ": "El 22", "El 32       ": "El 32", "El 42       ": "El 42", "El 23       ": "El 23", "El 33       ": "El 33", "El 43       ": "El 43"})
list(df.columns.values)
# Out:
# ['%t           ',
#  'El 21       ',
#  'El 31       ',
#  'El 41       ',
#  'El 22       ',
#  'El 32       ',
#  'El 42       ',
#  'El 23       ',
#  'El 33       ',
#  'El 43       ']

# %%
df = pd.read_csv(Location, sep='\t',skiprows=[0,1,3] , index_col='%t           ')
#df.columns = ['El 21','El 31','El 41','El 22','El 32','El 42','El 23','El 33','El 43']
#df_new = df.rename(columns={"%t           ": "t", "El 21       ": "EL 21", "El 31       ": "El 31", "El 41       ": "El 41", "El 22       ": "El 22", "El 32       ": "El 32", "El 42       ": "El 42", "El 23       ": "El 23", "El 33       ": "El 33", "El 43       ": "El 43"}, index={'%t           ': 't'}, inplace=True)
#df_new
df
# Out:
#                El 21         El 31         El 41         El 22         \
# %t
# 0.00                  -2.84         -1.02         -7.05         -3.18
# 0.04                  -3.41         -3.30         -8.07         -2.39
# 0.08                  -4.77         -3.86         -5.80         -1.70
# 0.12                  -5.00         -3.41         -4.32         -2.27
# 0.16                  -3.30         -4.20         -4.09         -1.93
# ...                     ...           ...           ...           ...
# 301799.80              0.68          0.68          0.23         -0.23
# 301799.84             -1.02         -1.14          0.91          0.23
# 301799.88             -1.14         -3.41          0.91         -0.11
# 301799.92             -2.50         -6.36         -1.59         -2.05
# 301799.96             -4.55         -6.93         -4.32         -2.50
#
#                El 32         El 42         El 23         El 33         \
# %t
# ...

# %%
list(df.columns.values)
# Out:
# ['El 21       ',
#  'El 31       ',
#  'El 41       ',
#  'El 22       ',
#  'El 32       ',
#  'El 42       ',
#  'El 23       ',
#  'El 33       ',
#  'El 43       ']

# %%
df['El 21       '].plot(figsize=(100,10))

# %%
ax = df['El 21       '].plot(figsize=(100,10), title='El 21')
ax.set_xlabel("time")
ax.set_ylabel("Amplitude [µV]")
# Out:
# Text(0, 0.5, 'Amplitude [µV]')

# %%
for col in df.columns:
    df[col].plot(figsize=(100,10), title='All Electrodes');
