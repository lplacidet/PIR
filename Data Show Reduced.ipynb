# %%
# Import all libraries needed for the tutorial

# General syntax to import specific functions in a library: 
##from (library) import (specific library function)
from pandas import DataFrame, read_csv

# General syntax to import a library but no functions: 
##import (library) as (give the library a nickname/alias)
import matplotlib.pyplot as plt
import pandas as pd #this is how I usually import pandas
import sys #only needed to determine Python version number
import matplotlib #only needed to determine Matplotlib version number

# Enable inline plotting
# %matplotlib inline

# %%
print('Python version ' + sys.version)
print('Pandas version ' + pd.__version__)
print('Matplotlib version ' + matplotlib.__version__)
# Out:
# Python version 3.7.4 (default, Aug 13 2019, 15:17:50)
# [Clang 4.0.1 (tags/RELEASE_401/final)]
# Pandas version 0.25.1
# Matplotlib version 3.1.1

# %%
# file path of csv file
Location = r'/Users/louiseplacidet/Desktop/PIR/Data/data_spikes/E18KABaseline_Bcut_reduced.txt'

# create dataframe
df = pd.read_csv(Location, sep='\t')
df
# Out:
#      t             El 21         El 31         El 41         El 22         \
# 0            0.00         -2.84         -1.02         -7.05         -3.18
# 1            0.04         -3.41         -3.30         -8.07         -2.39
# 2            0.08         -4.77         -3.86         -5.80         -1.70
# 3            0.12         -5.00         -3.41         -4.32         -2.27
# 4            0.16         -3.30         -4.20         -4.09         -1.93
# ..            ...           ...           ...           ...           ...
# 621         24.84         -0.91         -2.27         -3.41         -6.14
# 622         24.88          2.50          0.00         -2.16         -2.95
# 623         24.92          1.25          1.82         -1.02          0.00
# 624         24.96         -1.25          2.73         -0.34          2.73
# 625         25.00         -2.50          4.89         -0.80          4.09
#
#      El 32         El 42         El 23         El 33         \
# 0           -3.41         -3.30         -2.27         -1.36
# 1           -3.75         -2.27         -2.50         -2.27
# 2           -2.73         -0.34         -2.95         -2.27
# 3           -2.84          0.45         -4.43         -3.64
# 4           -4.55          1.14         -5.57         -3.52
# ..            ...           ...           ...           ...
# 621         -0.80         -1.25         -2.84         -0.11
# 622          0.00          0.00         -1.59          0.45
# 623          0.11         -0.68         -0.80         -0.23
# 624          0.11         -2.05         -0.91         -0.91
# 625          0.34         -2.61          0.34         -0.68
#
#      El 43
# 0                  -2.95
# 1                  -0.68
# 2                   0.11
# 3                  -1.48
# 4                  -1.82
# ..                   ...
# 621                -0.68
# 622                -0.57
# 623                -1.02
# 624                 0.57
# 625                 2.73
#
# [626 rows x 10 columns]

# %%
list(df.columns.values)
# Out:
# ['t           ',
#  'El 21       ',
#  'El 31       ',
#  'El 41       ',
#  'El 22       ',
#  'El 32       ',
#  'El 42       ',
#  'El 23       ',
#  'El 33       ',
#  'El 43              ']

# %%
df = pd.read_csv(Location, sep='\t', index_col='t           ')
df
# Out:
#               El 21         El 31         El 41         El 22         \
# t
# 0.00                 -2.84         -1.02         -7.05         -3.18
# 0.04                 -3.41         -3.30         -8.07         -2.39
# 0.08                 -4.77         -3.86         -5.80         -1.70
# 0.12                 -5.00         -3.41         -4.32         -2.27
# 0.16                 -3.30         -4.20         -4.09         -1.93
# ...                    ...           ...           ...           ...
# 24.84                -0.91         -2.27         -3.41         -6.14
# 24.88                 2.50          0.00         -2.16         -2.95
# 24.92                 1.25          1.82         -1.02          0.00
# 24.96                -1.25          2.73         -0.34          2.73
# 25.00                -2.50          4.89         -0.80          4.09
#
#               El 32         El 42         El 23         El 33         \
# t
# 0.00                 -3.41         -3.30         -2.27         -1.36
# 0.04                 -3.75         -2.27         -2.50         -2.27
# 0.08                 -2.73         -0.34         -2.95         -2.27
# 0.12                 -2.84          0.45         -4.43         -3.64
# 0.16                 -4.55          1.14         -5.57         -3.52
# ...                    ...           ...           ...           ...
# 24.84                -0.80         -1.25         -2.84         -0.11
# 24.88                 0.00          0.00         -1.59          0.45
# 24.92                 0.11         -0.68         -0.80         -0.23
# 24.96                 0.11         -2.05         -0.91         -0.91
# 25.00                 0.34         -2.61          0.34         -0.68
#
#               El 43
# t
# 0.00                        -2.95
# 0.04                        -0.68
# 0.08                         0.11
# 0.12                        -1.48
# 0.16                        -1.82
# ...                           ...
# 24.84                       -0.68
# 24.88                       -0.57
# 24.92                       -1.02
# 24.96                        0.57
# 25.00                        2.73
#
# [626 rows x 9 columns]

# %%
df['El 21       '].plot();

# %%
df['El 21       '].plot(figsize=(100,10));
